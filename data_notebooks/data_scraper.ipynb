# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time
from datetime import datetime, timedelta
import pytz
# %matplotlib inline
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
API_KEY = '39c094dc26939f21aab4314415efcd6f'
MASS_BOOKS = ['draftkings', 'fanduel', 'betmgm', 'williamhill_us', 'espnbet', 'ballybet']
ODDS_KEYS = ['basketball_nba', 'americanfootball_nfl']
ODDS_KEYS2 = ['basketball_nba', 'basketball_ncaab','icehockey_nhl','tennis_atp_us_open', 'tennis_wta_us_open']
REGIONS = ['us', 'us2']
S3_PATH = 's3://moneygans-data/'


#Converts UNIX timestamp to ISO format for readability
def ts_to_iso(ts):  
    tz = pytz.timezone('America/Los_Angeles')
    return datetime.fromtimestamp(ts, tz).isoformat()

def extract_time(iso_timestamp):
    # Parse the ISO timestamp
    dt = datetime.fromisoformat(iso_timestamp)
    # Format only hours and minutes
    return dt.strftime("%H:%M")

#Gets Date from ISO Timestamp
def get_date(s):
    return s.split('T')[0] 


#Can do this parallely for different sports eventually
def get_raw_odds(sport):
    response_dfs = []
    for region in REGIONS:
        odds_url = f'https://api.the-odds-api.com/v4/sports/{sport}/odds/?apiKey={API_KEY}&regions={region}&markets=h2h&oddsFormat=american&dateFormat=unix'
        response_dfs.append(pd.json_normalize(requests.get(odds_url).json()))
    response_df = pd.concat([response_dfs[0], response_dfs[1]])
    
    #Remove events that are not from today
    response_df = response_df[response_df['commence_time'].apply(ts_to_iso).apply(get_date) == get_date(ts_to_iso(time.time()))]
    return response_df

def convert_to_hours(seconds):
    hours = seconds / 3600
    return hours

# %%
def format_df(response_df):
    """This Function takes in the API response and returns a formatted dataframe to later be processed.
    
    Args:
        response_df: (pd.DataFrame): Formatted json dataframe returned by api call
    
    Returns:
        pd.DataFrame: formatted dataframe to be later used for analysis

    """
    new_df = pd.DataFrame()
    #Iterates through bookmakers to extract odds
    for i, row in enumerate(response_df.iterrows()):
        index, data = row  # Unpack the tuple
        for book in data['bookmakers']:
            if book['key'] in MASS_BOOKS:
                new_row = data.drop('bookmakers')
                new_row['book'] = book['key']
                if book['markets'][0]['outcomes'][0]['name'] == new_row['home_team']:
                    new_row['home_money'] = book['markets'][0]['outcomes'][0]['price']
                    new_row['away_money'] = book['markets'][0]['outcomes'][1]['price']
                else:
                    new_row['home_money'] = book['markets'][0]['outcomes'][1]['price']
                    new_row['away_money'] = book['markets'][0]['outcomes'][0]['price']
                
                #Sets positive and negative moneyline variables
                if new_row['home_money'] > 0 and new_row['away_money'] < 0:
                    new_row['pos_money'] = new_row['home_money']
                    new_row['neg_money'] = new_row['away_money']
                elif new_row['home_money'] < 0 and new_row['away_money'] > 0:
                    new_row['pos_money'] = new_row['away_money']
                    new_row['neg_money'] = new_row['home_money']
                #If both moneylines are negative, postive moneyline will be the less negative of the two
                elif new_row['home_money'] < 0 and new_row['away_money'] < 0:
                    new_row['pos_money'] = max(new_row['home_money'],new_row['away_money'])
                    new_row['neg_money'] = min(new_row['home_money'],new_row['away_money'])



                #Adds column representing the time before the game starts in iso format
                #Time to game represents the time in 
                new_row['commence_time_pst'] = ts_to_iso(new_row['commence_time'])
                new_row['ts'] = time.time()
                new_row['game_time_ms'] =  new_row['ts'] - new_row['commence_time']
                new_row['game_time_hrs'] = convert_to_hours(new_row['game_time_ms'])
                new_row['last_update'] = book['markets'][0]['last_update']
                new_row['last_update_pst'] = ts_to_iso(new_row['last_update'])
                new_row['true_game_time_ms'] = new_row['last_update'] - new_row['commence_time']
                new_df = pd.concat([new_df, new_row], axis=1)
        # print(new_row)
    
    return new_df.T.reset_index(drop=True)

# %%
odds_raw = get_raw_odds(ODDS_KEYS[0])
format_df(odds_raw)
# Out:
#                                   id       sport_key sport_title  \
# 0   b6a441be8a8bfbc98f81f10fc9871242  basketball_nba         NBA
# 1   b6a441be8a8bfbc98f81f10fc9871242  basketball_nba         NBA
# 2   b6a441be8a8bfbc98f81f10fc9871242  basketball_nba         NBA
# 3   b6a441be8a8bfbc98f81f10fc9871242  basketball_nba         NBA
# 4   6804bef5473a20af6f1961f35222d029  basketball_nba         NBA
# 5   6804bef5473a20af6f1961f35222d029  basketball_nba         NBA
# 6   6804bef5473a20af6f1961f35222d029  basketball_nba         NBA
# 7   6804bef5473a20af6f1961f35222d029  basketball_nba         NBA
# 8   d087a0df2d70a552190892fb8437a2f8  basketball_nba         NBA
# 9   d087a0df2d70a552190892fb8437a2f8  basketball_nba         NBA
# 10  d087a0df2d70a552190892fb8437a2f8  basketball_nba         NBA
# 11  d087a0df2d70a552190892fb8437a2f8  basketball_nba         NBA
# 12  c964ff35d3877fe2cc177840e7849b56  basketball_nba         NBA
# 13  c964ff35d3877fe2cc177840e7849b56  basketball_nba         NBA
# 14  c964ff35d3877fe2cc177840e7849b56  basketball_nba         NBA
# 15  c964ff35d3877fe2cc177840e7849b56  basketball_nba         NBA
# 16  d0795fd9220c18669a07a0482b1c7d12  basketball_nba         NBA
# 17  d0795fd9220c18669a07a0482b1c7d12  basketball_nba         NBA
# 18  d0795fd9220c18669a07a0482b1c7d12  basketball_nba         NBA
# 19  d0795fd9220c18669a07a0482b1c7d12  basketball_nba         NBA
# 20  dd70c59ef34cad65eae610a55f9f1b1f  basketball_nba         NBA
# 21  dd70c59ef34cad65eae610a55f9f1b1f  basketball_nba         NBA
# 22  dd70c59ef34cad65eae610a55f9f1b1f  basketball_nba         NBA
# 23  dd70c59ef34cad65eae610a55f9f1b1f  basketball_nba         NBA
# 24  d35ddee1c4251399c3eca618798adf8c  basketball_nba         NBA
# 25  d35ddee1c4251399c3eca618798adf8c  basketball_nba         NBA
# 26  d35ddee1c4251399c3eca618798adf8c  basketball_nba         NBA
# 27  d35ddee1c4251399c3eca618798adf8c  basketball_nba         NBA
# 28  9d4e84b4698222b4a7268cc54d4702e2  basketball_nba         NBA
# 29  9d4e84b4698222b4a7268cc54d4702e2  basketball_nba         NBA
# 30  9d4e84b4698222b4a7268cc54d4702e2  basketball_nba         NBA
# 31  9d4e84b4698222b4a7268cc54d4702e2  basketball_nba         NBA
# 32  c240b61df0fe48c2f99bd6a768215273  basketball_nba         NBA
# 33  c240b61df0fe48c2f99bd6a768215273  basketball_nba         NBA
# 34  c240b61df0fe48c2f99bd6a768215273  basketball_nba         NBA
# 35  c240b61df0fe48c2f99bd6a768215273  basketball_nba         NBA
# 36  1f282e297378b2bf5962666aff292e7c  basketball_nba         NBA
# 37  1f282e297378b2bf5962666aff292e7c  basketball_nba         NBA
# 38  1f282e297378b2bf5962666aff292e7c  basketball_nba         NBA
# 39  1f282e297378b2bf5962666aff292e7c  basketball_nba         NBA
# 40  b6a441be8a8bfbc98f81f10fc9871242  basketball_nba         NBA
# 41  b6a441be8a8bfbc98f81f10fc9871242  basketball_nba         NBA
# 42  6804bef5473a20af6f1961f35222d029  basketball_nba         NBA
# 43  6804bef5473a20af6f1961f35222d029  basketball_nba         NBA
# 44  d087a0df2d70a552190892fb8437a2f8  basketball_nba         NBA
# 45  d087a0df2d70a552190892fb8437a2f8  basketball_nba         NBA
# 46  c964ff35d3877fe2cc177840e7849b56  basketball_nba         NBA
# 47  c964ff35d3877fe2cc177840e7849b56  basketball_nba         NBA
# 48  d0795fd9220c18669a07a0482b1c7d12  basketball_nba         NBA
# 49  d0795fd9220c18669a07a0482b1c7d12  basketball_nba         NBA
# 50  dd70c59ef34cad65eae610a55f9f1b1f  basketball_nba         NBA
# 51  dd70c59ef34cad65eae610a55f9f1b1f  basketball_nba         NBA
# 52  d35ddee1c4251399c3eca618798adf8c  basketball_nba         NBA
# 53  d35ddee1c4251399c3eca618798adf8c  basketball_nba         NBA
# 54  9d4e84b4698222b4a7268cc54d4702e2  basketball_nba         NBA
# 55  9d4e84b4698222b4a7268cc54d4702e2  basketball_nba         NBA
# 56  c240b61df0fe48c2f99bd6a768215273  basketball_nba         NBA
# 57  c240b61df0fe48c2f99bd6a768215273  basketball_nba         NBA
# 58  1f282e297378b2bf5962666aff292e7c  basketball_nba         NBA
# 59  1f282e297378b2bf5962666aff292e7c  basketball_nba         NBA
#
#    commence_time             home_team               away_team  \
# 0     1730585400     Charlotte Hornets          Boston Celtics
# 1     1730585400     Charlotte Hornets          Boston Celtics
# 2     1730585400     Charlotte Hornets          Boston Celtics
# 3     1730585400     Charlotte Hornets          Boston Celtics
# 4     1730590800    Philadelphia 76ers       Memphis Grizzlies
# 5     1730590800    Philadelphia 76ers       Memphis Grizzlies
# 6     1730590800    Philadelphia 76ers       Memphis Grizzlies
# 7     1730590800    Philadelphia 76ers       Memphis Grizzlies
# 8     1730590800       Toronto Raptors        Sacramento Kings
# 9     1730590800       Toronto Raptors        Sacramento Kings
# 10    1730590800       Toronto Raptors        Sacramento Kings
# 11    1730590800       Toronto Raptors        Sacramento Kings
# 12    1730592600       Milwaukee Bucks     Cleveland Cavaliers
# 13    1730592600       Milwaukee Bucks     Cleveland Cavaliers
# 14    1730592600       Milwaukee Bucks     Cleveland Cavaliers
# 15    1730592600       Milwaukee Bucks     Cleveland Cavaliers
# 16    1730592600       Houston Rockets   Golden State Warriors
# 17    1730592600       Houston Rockets   Golden State Warriors
# 18    1730592600       Houston Rockets   Golden State Warriors
# 19    1730592600       Houston Rockets   Golden State Warriors
# 20    1730592600     San Antonio Spurs  Minnesota Timberwolves
# 21    1730592600     San Antonio Spurs  Minnesota Timberwolves
# 22    1730592600     San Antonio Spurs  Minnesota Timberwolves
# 23    1730592600     San Antonio Spurs  Minnesota Timberwolves
# 24    1730598000    Washington Wizards              Miami Heat
# 25    1730598000    Washington Wizards              Miami Heat
# 26    1730598000    Washington Wizards              Miami Heat
# 27    1730598000    Washington Wizards              Miami Heat
# 28    1730599800        Denver Nuggets               Utah Jazz
# 29    1730599800        Denver Nuggets               Utah Jazz
# 30    1730599800        Denver Nuggets               Utah Jazz
# 31    1730599800        Denver Nuggets               Utah Jazz
# 32    1730599800          Phoenix Suns  Portland Trail Blazers
# 33    1730599800          Phoenix Suns  Portland Trail Blazers
# 34    1730599800          Phoenix Suns  Portland Trail Blazers
# 35    1730599800          Phoenix Suns  Portland Trail Blazers
# 36    1730601600  Los Angeles Clippers   Oklahoma City Thunder
# 37    1730601600  Los Angeles Clippers   Oklahoma City Thunder
# 38    1730601600  Los Angeles Clippers   Oklahoma City Thunder
# 39    1730601600  Los Angeles Clippers   Oklahoma City Thunder
# 40    1730585400     Charlotte Hornets          Boston Celtics
# 41    1730585400     Charlotte Hornets          Boston Celtics
# 42    1730590800    Philadelphia 76ers       Memphis Grizzlies
# 43    1730590800    Philadelphia 76ers       Memphis Grizzlies
# 44    1730590800       Toronto Raptors        Sacramento Kings
# 45    1730590800       Toronto Raptors        Sacramento Kings
# 46    1730592600       Milwaukee Bucks     Cleveland Cavaliers
# 47    1730592600       Milwaukee Bucks     Cleveland Cavaliers
# 48    1730592600       Houston Rockets   Golden State Warriors
# 49    1730592600       Houston Rockets   Golden State Warriors
# 50    1730592600     San Antonio Spurs  Minnesota Timberwolves
# 51    1730592600     San Antonio Spurs  Minnesota Timberwolves
# 52    1730598000    Washington Wizards              Miami Heat
# 53    1730598000    Washington Wizards              Miami Heat
# 54    1730599800        Denver Nuggets               Utah Jazz
# 55    1730599800        Denver Nuggets               Utah Jazz
# 56    1730599800          Phoenix Suns  Portland Trail Blazers
# 57    1730599800          Phoenix Suns  Portland Trail Blazers
# 58    1730601600  Los Angeles Clippers   Oklahoma City Thunder
# 59    1730601600  Los Angeles Clippers   Oklahoma City Thunder
#
#               book home_money away_money pos_money neg_money  \
# 0       draftkings        410       -550       410      -550
# 1   williamhill_us        400       -550       400      -550
# 2           betmgm        400       -550       400      -550
# 3          fanduel        380       -500       380      -500
# 4       draftkings       -108       -112      -108      -112
# 5          fanduel       -110       -106      -106      -110
# 6   williamhill_us       -110       -110      -110      -110
# 7           betmgm       -110       -110      -110      -110
# 8       draftkings        270       -340       270      -340
# 9          fanduel        270       -335       270      -335
# 10          betmgm        275       -350       275      -350
# 11  williamhill_us        275       -350       275      -350
# 12      draftkings       -125        105       105      -125
# 13         fanduel       -120        102       102      -120
# 14  williamhill_us       -125        105       105      -125
# 15          betmgm       -130        105       105      -130
# 16      draftkings       -192        160       160      -192
# 17         fanduel       -188        158       158      -188
# 18  williamhill_us       -178        150       150      -178
# 19          betmgm       -190        155       155      -190
# 20      draftkings        140       -166       140      -166
# 21          betmgm        140       -165       140      -165
# 22  williamhill_us        143       -170       143      -170
# 23         fanduel        136       -162       136      -162
# 24      draftkings        350       -455       350      -455
# 25  williamhill_us        360       -480       360      -480
# 26         fanduel        320       -405       320      -405
# 27          betmgm        340       -450       340      -450
# 28      draftkings       -575        425       425      -575
# 29         fanduel       -560        420       420      -560
# 30          betmgm       -600        425       425      -600
# 31  williamhill_us       -600        430       430      -600
# 32      draftkings       -950        625       625      -950
# 33         fanduel       -950        640       640      -950
# 34          betmgm      -1000        625       625     -1000
# 35  williamhill_us       -900        600       600      -900
# 36      draftkings        185       -225       185      -225
# 37          betmgm        185       -225       185      -225
# 38  williamhill_us        185       -225       185      -225
# 39         fanduel        184       -220       184      -220
# 40         espnbet        380       -500       380      -500
# 41        ballybet        380       -500       380      -500
# 42         espnbet       -110       -110      -110      -110
# 43        ballybet       -106       -112      -106      -112
# 44         espnbet        250       -320       250      -320
# 45        ballybet        285       -360       285      -360
# 46         espnbet       -125        105       105      -125
# 47        ballybet       -125        105       105      -125
# 48         espnbet       -190        160       160      -190
# 49        ballybet       -200        165       165      -200
# 50         espnbet        140       -170       140      -170
# 51        ballybet        135       -159       135      -159
# 52         espnbet        320       -420       320      -420
# 53        ballybet        310       -400       310      -400
# 54         espnbet       -550        400       400      -550
# 55        ballybet       -530        390       390      -530
# 56         espnbet       -950        620       620      -950
# 57        ballybet       -835        575       575      -835
# 58         espnbet        185       -225       185      -225
# 59        ballybet        185       -225       185      -225
#
#             commence_time_pst                 ts  game_time_ms game_time_hrs  \
# 0   2024-11-02T15:10:00-07:00  1730573083.914285 -12316.085715     -3.421135
# 1   2024-11-02T15:10:00-07:00  1730573083.918448 -12316.081552     -3.421134
# 2   2024-11-02T15:10:00-07:00  1730573083.922283 -12316.077717     -3.421133
# 3   2024-11-02T15:10:00-07:00  1730573083.925621 -12316.074379     -3.421132
# 4   2024-11-02T16:40:00-07:00  1730573083.928874 -17716.071126     -4.921131
# 5   2024-11-02T16:40:00-07:00  1730573083.932035 -17716.067965      -4.92113
# 6   2024-11-02T16:40:00-07:00  1730573083.934958 -17716.065042     -4.921129
# 7   2024-11-02T16:40:00-07:00  1730573083.937916 -17716.062084     -4.921128
# 8   2024-11-02T16:40:00-07:00  1730573083.940875 -17716.059125     -4.921128
# 9   2024-11-02T16:40:00-07:00  1730573083.943706 -17716.056294     -4.921127
# 10  2024-11-02T16:40:00-07:00  1730573083.946326 -17716.053674     -4.921126
# 11  2024-11-02T16:40:00-07:00  1730573083.949013 -17716.050987     -4.921125
# 12  2024-11-02T17:10:00-07:00  1730573083.951721 -19516.048279     -5.421125
# 13  2024-11-02T17:10:00-07:00  1730573083.954299 -19516.045701     -5.421124
# 14  2024-11-02T17:10:00-07:00  1730573083.957017 -19516.042983     -5.421123
# 15  2024-11-02T17:10:00-07:00  1730573083.959837 -19516.040163     -5.421122
# 16  2024-11-02T17:10:00-07:00  1730573083.962418 -19516.037582     -5.421122
# 17  2024-11-02T17:10:00-07:00   1730573083.96496  -19516.03504     -5.421121
# 18  2024-11-02T17:10:00-07:00  1730573083.967759 -19516.032241      -5.42112
# 19  2024-11-02T17:10:00-07:00  1730573083.970194 -19516.029806     -5.421119
# 20  2024-11-02T17:10:00-07:00  1730573083.972846 -19516.027154     -5.421119
# 21  2024-11-02T17:10:00-07:00  1730573083.975308 -19516.024692     -5.421118
# 22  2024-11-02T17:10:00-07:00   1730573083.97778  -19516.02222     -5.421117
# 23  2024-11-02T17:10:00-07:00  1730573083.980267 -19516.019733     -5.421117
# 24  2024-11-02T18:40:00-07:00   1730573083.98273  -24916.01727     -6.921116
# 25  2024-11-02T18:40:00-07:00  1730573083.985134 -24916.014866     -6.921115
# 26  2024-11-02T18:40:00-07:00  1730573083.987634 -24916.012366     -6.921115
# 27  2024-11-02T18:40:00-07:00  1730573083.990061 -24916.009939     -6.921114
# 28  2024-11-02T19:10:00-07:00  1730573083.992506 -26716.007494     -7.421113
# 29  2024-11-02T19:10:00-07:00  1730573083.995025 -26716.004975     -7.421112
# 30  2024-11-02T19:10:00-07:00  1730573083.997527 -26716.002473     -7.421112
# 31  2024-11-02T19:10:00-07:00  1730573083.999927 -26716.000073     -7.421111
# 32  2024-11-02T19:10:00-07:00  1730573084.002418 -26715.997582      -7.42111
# 33  2024-11-02T19:10:00-07:00  1730573084.004883 -26715.995117      -7.42111
# 34  2024-11-02T19:10:00-07:00  1730573084.007282 -26715.992718     -7.421109
# 35  2024-11-02T19:10:00-07:00  1730573084.009696 -26715.990304     -7.421108
# 36  2024-11-02T19:40:00-07:00  1730573084.012448 -28515.987552     -7.921108
# 37  2024-11-02T19:40:00-07:00  1730573084.015212 -28515.984788     -7.921107
# 38  2024-11-02T19:40:00-07:00  1730573084.017773 -28515.982227     -7.921106
# 39  2024-11-02T19:40:00-07:00  1730573084.020505 -28515.979495     -7.921105
# 40  2024-11-02T15:10:00-07:00  1730573084.023055 -12315.976945     -3.421105
# 41  2024-11-02T15:10:00-07:00  1730573084.026046 -12315.973954     -3.421104
# 42  2024-11-02T16:40:00-07:00  1730573084.028868 -17715.971132     -4.921103
# 43  2024-11-02T16:40:00-07:00  1730573084.031373 -17715.968627     -4.921102
# 44  2024-11-02T16:40:00-07:00  1730573084.033838 -17715.966162     -4.921102
# 45  2024-11-02T16:40:00-07:00  1730573084.037183 -17715.962817     -4.921101
# 46  2024-11-02T17:10:00-07:00  1730573084.040176 -19515.959824       -5.4211
# 47  2024-11-02T17:10:00-07:00  1730573084.042652 -19515.957348     -5.421099
# 48  2024-11-02T17:10:00-07:00  1730573084.045143 -19515.954857     -5.421099
# 49  2024-11-02T17:10:00-07:00  1730573084.047927 -19515.952073     -5.421098
# 50  2024-11-02T17:10:00-07:00  1730573084.050441 -19515.949559     -5.421097
# 51  2024-11-02T17:10:00-07:00  1730573084.052956 -19515.947044     -5.421096
# 52  2024-11-02T18:40:00-07:00  1730573084.056084 -24915.943916     -6.921096
# 53  2024-11-02T18:40:00-07:00    1730573084.0587   -24915.9413     -6.921095
# 54  2024-11-02T19:10:00-07:00  1730573084.061812 -26715.938188     -7.421094
# 55  2024-11-02T19:10:00-07:00  1730573084.064437 -26715.935563     -7.421093
# 56  2024-11-02T19:10:00-07:00  1730573084.066889 -26715.933111     -7.421093
# 57  2024-11-02T19:10:00-07:00  1730573084.069602 -26715.930398     -7.421092
# 58  2024-11-02T19:40:00-07:00  1730573084.072599 -28515.927401     -7.921091
# 59  2024-11-02T19:40:00-07:00  1730573084.075292 -28515.924708      -7.92109
#
#    last_update            last_update_pst true_game_time_ms
# 0   1730573019  2024-11-02T11:43:39-07:00            -12381
# 1   1730573019  2024-11-02T11:43:39-07:00            -12381
# 2   1730573019  2024-11-02T11:43:39-07:00            -12381
# 3   1730573020  2024-11-02T11:43:40-07:00            -12380
# 4   1730573019  2024-11-02T11:43:39-07:00            -17781
# 5   1730573020  2024-11-02T11:43:40-07:00            -17780
# 6   1730573019  2024-11-02T11:43:39-07:00            -17781
# 7   1730573019  2024-11-02T11:43:39-07:00            -17781
# 8   1730573019  2024-11-02T11:43:39-07:00            -17781
# 9   1730573020  2024-11-02T11:43:40-07:00            -17780
# 10  1730573019  2024-11-02T11:43:39-07:00            -17781
# 11  1730573019  2024-11-02T11:43:39-07:00            -17781
# 12  1730573019  2024-11-02T11:43:39-07:00            -19581
# 13  1730573020  2024-11-02T11:43:40-07:00            -19580
# 14  1730573019  2024-11-02T11:43:39-07:00            -19581
# 15  1730573019  2024-11-02T11:43:39-07:00            -19581
# 16  1730573019  2024-11-02T11:43:39-07:00            -19581
# 17  1730573020  2024-11-02T11:43:40-07:00            -19580
# 18  1730573019  2024-11-02T11:43:39-07:00            -19581
# 19  1730573019  2024-11-02T11:43:39-07:00            -19581
# 20  1730573019  2024-11-02T11:43:39-07:00            -19581
# 21  1730573019  2024-11-02T11:43:39-07:00            -19581
# 22  1730573019  2024-11-02T11:43:39-07:00            -19581
# 23  1730573020  2024-11-02T11:43:40-07:00            -19580
# 24  1730573019  2024-11-02T11:43:39-07:00            -24981
# 25  1730573019  2024-11-02T11:43:39-07:00            -24981
# 26  1730573020  2024-11-02T11:43:40-07:00            -24980
# 27  1730573019  2024-11-02T11:43:39-07:00            -24981
# 28  1730573019  2024-11-02T11:43:39-07:00            -26781
# 29  1730573020  2024-11-02T11:43:40-07:00            -26780
# 30  1730573019  2024-11-02T11:43:39-07:00            -26781
# 31  1730573019  2024-11-02T11:43:39-07:00            -26781
# 32  1730573019  2024-11-02T11:43:39-07:00            -26781
# 33  1730573020  2024-11-02T11:43:40-07:00            -26780
# 34  1730573019  2024-11-02T11:43:39-07:00            -26781
# 35  1730573019  2024-11-02T11:43:39-07:00            -26781
# 36  1730573019  2024-11-02T11:43:39-07:00            -28581
# 37  1730573019  2024-11-02T11:43:39-07:00            -28581
# 38  1730573019  2024-11-02T11:43:39-07:00            -28581
# 39  1730573020  2024-11-02T11:43:40-07:00            -28580
# 40  1730573020  2024-11-02T11:43:40-07:00            -12380
# 41  1730573020  2024-11-02T11:43:40-07:00            -12380
# 42  1730573020  2024-11-02T11:43:40-07:00            -17780
# 43  1730573020  2024-11-02T11:43:40-07:00            -17780
# 44  1730573020  2024-11-02T11:43:40-07:00            -17780
# 45  1730573020  2024-11-02T11:43:40-07:00            -17780
# 46  1730573020  2024-11-02T11:43:40-07:00            -19580
# 47  1730573020  2024-11-02T11:43:40-07:00            -19580
# 48  1730573020  2024-11-02T11:43:40-07:00            -19580
# 49  1730573020  2024-11-02T11:43:40-07:00            -19580
# 50  1730573020  2024-11-02T11:43:40-07:00            -19580
# 51  1730573020  2024-11-02T11:43:40-07:00            -19580
# 52  1730573020  2024-11-02T11:43:40-07:00            -24980
# 53  1730573020  2024-11-02T11:43:40-07:00            -24980
# 54  1730573020  2024-11-02T11:43:40-07:00            -26780
# 55  1730573020  2024-11-02T11:43:40-07:00            -26780
# 56  1730573020  2024-11-02T11:43:40-07:00            -26780
# 57  1730573020  2024-11-02T11:43:40-07:00            -26780
# 58  1730573020  2024-11-02T11:43:40-07:00            -28580
# 59  1730573020  2024-11-02T11:43:40-07:00            -28580

# %%
odds_clean = pd.read_csv('nba_test.csv')
first_start_time = odds_clean[odds_clean['commence_time'] == odds_clean['commence_time'].min()].iloc[0]['commence_time_est']
start_time_lag = (datetime.fromisoformat(first_start_time) - timedelta(minutes=5)).strftime('%H:%M')

# %%
start_time_lag
# Out:
# '19:05'

# %%
def get_current_date_time_est():
    # Define the Eastern Standard Time zone
    pst_timezone = pytz.timezone('America/Los_Angeles')
    
    # Get the current time in UTC
    utc_time = datetime.now(pytz.utc)
    
    # Convert the current UTC time to EST time
    pst_time = utc_time.astimezone(pst_timezone)
    
    return pst_time

# %%
def save_live_odds(data, date, time, sport):
    s3_path = S3_PATH+f'{sport}/{date}/live_odds/{sport}_{date}_{time}.parquet'
    if not data.empty:
        data.to_parquet(s3_path, index=False)
    
save_live_odds(get_current_date_time_est().strftime('%Y-%m-%d'), time.time(), ODDS_KEYS[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/rl/q68vvj6j245f29dbc9dvn47c0000gn/T/ipykernel_22520/1924087201.py in <module>
#       4         data.to_parquet(s3_path, index=False)
#       5
# ----> 6 save_live_odds(get_current_date_time_est().strftime('%Y-%m-%d'), time.time(), ODDS_KEYS[0])
#
# TypeError: save_live_odds() missing 1 required positional argument: 'sport'

# %%
def sleep_until_out_of_interval(start_time: str, end_time: str):
    """
    Sleeps until the current time is outside the given time range.

    :param start_time: Start time in 'HH:MM' 24-hour format (e.g., '06:00').
    :param end_time: End time in 'HH:MM' 24-hour format (e.g., '01:00').
    """
    # Use Eastern Time zone
    tz = pytz.timezone('America/Los_Angeles')
    now = datetime.now(tz)
    current_time = now.time()

    # Convert start_time and end_time to datetime objects (today's date)
    start = datetime.combine(now.date(), datetime.strptime(start_time, '%H:%M').time())
    end = datetime.combine(now.date(), datetime.strptime(end_time, '%H:%M').time())

    # Localize start and end times to the Eastern Time zone
    start = tz.localize(start)
    end = tz.localize(end)

    # If the end time is before the start time, it means the interval spans midnight
    if end < start:
        end += timedelta(days=1)  # Adjust the end time to the next day if it spans midnight

    # Check if the current time is in the interval
    if start <= now <= end:
        # Calculate how long to sleep until the end of the interval
        sleep_duration = (end - now).total_seconds()
        print(f"Current time is within the interval {start_time} - {end_time} PST, sleeping for {sleep_duration} seconds.")
        time.sleep(sleep_duration)
    #else:
        #print("Current time is outside the specified interval, no sleep.")

# %%
def get_current_date_time_est():
    # Define the Eastern Standard Time zone
    est_timezone = pytz.timezone('America/Los_Angeles')
    
    # Get the current time in UTC
    utc_time = datetime.now(pytz.utc)
    
    # Convert the current UTC time to EST time
    est_time = utc_time.astimezone(est_timezone)
    
    return est_time



def execute_30():
    while True:
        est_time = get_current_date_time_est()

        seconds = est_time.second
        
        # Calculate the delay to the next 0 or 30 seconds
        if seconds < 30:
            delay = 30 - seconds
        else:
            delay = 60 - seconds
        
        # Wait until the aligned time
        time.sleep(delay)

        # After the initial alignment, execute every 30 seconds
        while True:
            data = pd.read_csv('nba_test.csv')
            first_start_time = data[data['commence_time'] == data['commence_time'].min()].iloc[0]['commence_time_est']
            start_time_lag = (datetime.fromisoformat(first_start_time) - timedelta(minutes=5)).strftime('%H:%M')
            
            # Sleeps betwen 2AM and 5 mins before first game
            print(start_time_lag)
            sleep_until_out_of_interval('02:00', start_time_lag)
            
            est_time = get_current_date_time_est()
            curr_date = est_time.strftime('%Y-%m-%d')
            curr_time = est_time.strftime('%H:%M:%S')
            start_time = time.time()
            
            print("Save executed at", curr_date, curr_time)
            # for sport in ODDS_KEYS:
            save_live_odds(data,curr_date,curr_time,ODDS_KEYS[0])
            processing_time = time.time() - start_time
            # Sleep for the remainder of the 30 seconds
            time.sleep(max(30 - processing_time, 0))


if __name__ == '__main__':
    execute_30()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/rl/q68vvj6j245f29dbc9dvn47c0000gn/T/ipykernel_22520/3952197851.py in <module>
#      52
#      53 if __name__ == '__main__':
# ---> 54     execute_30()
#      55
#      56
#
# /var/folders/rl/q68vvj6j245f29dbc9dvn47c0000gn/T/ipykernel_22520/3952197851.py in execute_30()
#      26
#      27         # Wait until the aligned time
# ---> 28         time.sleep(delay)
#      29
#      30         # After the initial alignment, execute every 30 seconds
#
# KeyboardInterrupt:
